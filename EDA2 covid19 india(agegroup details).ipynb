# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import csv
from sklearn.preprocessing import LabelEncoder
# %matplotlib inline

covid=pd.read_csv('AgeGroupDetails.csv')

# %%
print(covid.shape)
# Out:
# (10, 4)

# %%
print(covid.columns)
# Out:
# Index(['Sno', 'AgeGroup', 'TotalCases', 'Percentage'], dtype='object')

# %%
covid.head()
# Out:
#    Sno AgeGroup  TotalCases Percentage
# 0    1      0-9          22      3.18%
# 1    2    10-19          27      3.90%
# 2    3    20-29         172     24.86%
# 3    4    30-39         146     21.10%
# 4    5    40-49         112     16.18%

# %%
covid.sort_values(by="TotalCases")
# Out:
#    Sno AgeGroup  TotalCases Percentage
# 9   10  Missing           9      1.30%
# 8    9     >=80          10      1.45%
# 0    1      0-9          22      3.18%
# 1    2    10-19          27      3.90%
# 7    8    70-79          28      4.05%
# 5    6    50-59          77     11.13%
# 6    7    60-69          89     12.86%
# 4    5    40-49         112     16.18%
# 3    4    30-39         146     21.10%
# 2    3    20-29         172     24.86%

# %%
#covid.sort_values(by="Percentage")
covid_dict=covid['AgeGroup'].value_counts().to_dict()
covid_dict
# Out:
# {'>=80': 1,
#  '10-19': 1,
#  'Missing': 1,
#  '50-59': 1,
#  '30-39': 1,
#  '70-79': 1,
#  '0-9': 1,
#  '20-29': 1,
#  '40-49': 1,
#  '60-69': 1}

# %%
dict={}

for i in covid_dict:
    covid_loc=covid[covid['AgeGroup'].str.contains(i)]
    dict.update({i:covid_loc["TotalCases"].max()})

# %%
dict_keys=dict.keys()
print(dict_keys,'\n')

dict_values=dict.values()
print(dict_values)
# Out:
# dict_keys(['>=80', '10-19', 'Missing', '50-59', '30-39', '70-79', '0-9', '20-29', '40-49', '60-69'])
#
# dict_values([10, 27, 9, 77, 146, 28, 22, 172, 112, 89])

# %%
plt.figure(figsize=(20,10))
ax=plt.bar(dict_keys,dict_values)
plt.xticks(rotation=90)
plt.title('Totalcases in each Agegroup',fontsize=44)
plt.xlabel('AgeGroup',fontsize=40)
plt.ylabel('Number of Cases',fontsize=40)
# Out:
# Text(0, 0.5, 'Number of Cases')

# %%
df=pd.DataFrame([3.18,3.90,24.86,21.10,16.18,11.13,12.86,4.05,1.45,1.30], index=['0-9','10-19','20-29','30-39','40-49','50-59','60-69','70-79','>=80','Missing'])
df.plot(kind='pie', subplots=True, figsize=(8, 8))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001B990E01518>],
#       dtype=object)
